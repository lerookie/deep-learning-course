# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
from scipy import misc

model = load_model('project04.h5')

# %%
def show_image(data):
    fig, axes = plt.subplots(1, )
    fig.subplots_adjust(hspace=0.5, wspace=0.5)
    plt.imshow(data)
    plt.show()
    
def load_image(filename):
    img = misc.imread(filename)
    img = misc.imresize(img, [299, 299], 'bilinear')
    return img

show_image(load_image('./data/satay.jpg'))

# %%
import csv

with open('./data/category_map.csv', mode='r') as f:
    reader = csv.reader(f)
    category_map = {row[0]:row[1] for row in reader}
    
print(category_map)
# Out:
# {'69': 'pot_wrap_meat', '105': 'mango_sticky_rice', '40': 'prawn_with_celery', '20': 'char_kway_teow', '122': '', '77': 'spicy_fish', '119': 'three_cup_chicken', '48': 'chives_omelette', '115': 'lotus_root_soup', '16': 'pork_trotters', '4': 'beef_noodles', '107': 'cucumber', '120': 'kang_kong', '92': 'saliva_chicken', 'category': 'category_label', '8': 'spicy_fish_soup', '26': 'chicken_wing', '101': 'burdock_root', '123': 'pork_ribs', '75': 'stinky_tofu', '66': 'fried_steam_meat', '116': 'winter_melon_soup', '46': 'glass_vermicelli', '102': 'sour_spicy_noodles', '17': 'sea_cucumber', '131': 'yu_sheng', '39': 'spring_onion', '79': 'pancake', '34': 'diced_chicken', '47': 'vegetable_omelette', '36': 'mushroom', '41': 'mixed_vegetables', '52': 'century_egg', '112': 'wanton_noodles', '11': 'beef_noodles', '49': 'tomato_omelette', '59': 'spicy_prawn', '124': 'green_bean_soup', '33': 'spicy_frog', '30': 'hot_dog_pastry', '24': 'rice_dumpling', '43': 'return_pot_meat', '57': 'spicy_lobster', '91': 'garlic_white_meat', '82': 'fried_chicken_drumstick', '71': 'curry_puff', '45': 'sweet_corn', '118': '', '29': 'kang_kong', '106': 'mapo_tofu', '125': 'tea_egg', '62': 'steamed_crab', '3': 'satay', '61': 'saliva_chicken', '95': 'tea_tree_mushroom', '55': 'vinegar_bok_choy', '87': 'pineapple_rice', '80': 'string_bean', '12': 'meat_and_potatoes', '67': 'meat_burger', '25': 'roast_chicken', '90': '', '50': 'hand_torn_cabbage', '114': 'liver', '51': 'small_fried_meat', '56': 'garlic_pork_ribs', '74': 'dough_fritter', '81': 'string_bean_with_eggplant', '13': 'stirfried_eggplant', '98': 'hokkien_prawn_noodles', '21': 'french_fries', '35': 'chinese_cabbage', '129': 'spicy_fish_pork_strip', '15': 'braised_pork', '130': 'bean_curd_skin', '14': 'pig_intestines', '19': 'braised_tofu', '18': 'pork_ribs', '22': 'chicken_feet', '89': 'chilli_crab', '60': 'xiao_long_bao', '108': 'mashed_potato', '7': 'herbal_soup', '127': 'chng_tng', '70': 'fish_soup', '126': 'century_egg_tofu', '65': 'spicy_fish_head', '104': 'sushi_roll', '54': 'sour_soup_fat_beef', '9': 'chicken_rice', '31': 'spicy_chicken', '2': 'curry', '78': 'spicy_braised_fish', '5': 'beef_brisket', '0': 'baked_beans', '6': 'steak', '103': 'kung_pow_chicken', '72': 'breaded_prawn', '94': 'cauliflower', '44': 'cuttlefish', '53': 'seaweed', '32': 'sea_snail', '88': 'sweet_sour_pork', '110': 'congee', '68': 'spicy_cold_noodles', '63': 'steamed_egg', '64': 'steamed_fish', '109': 'small_grain_porridge', '97': 'spicy_grilled_fish', '100': 'spicy_cold_noodles', '37': 'meat_strip', '83': 'fried_dumplings', '128': 'fried_rice', '28': 'choy_sum', '38': 'gluten', '76': 'fish_and_chips', '113': 'fried_egg', '10': 'spicy_meat', '58': 'fragrance_hot_pot', '42': 'green_bean', '96': 'grilled_eggplant', '84': 'stuffed_chilli', '86': 'earth_three_fresh', '93': 'clams', '99': 'chinese_ramen', '117': 'onion_roll', '27': 'scallion', '121': 'siew_mai', '23': 'braised_pork_belly', '73': 'spring_roll', '111': 'bibimbap', '1': 'roast_meat_rice', '85': 'mutton'}

# %%
predictions = model.predict(np.array([load_image('./data/satay.jpg'), \
                                      load_image('./data/satay2.jpg'), \
                                      load_image('./data/hotdog.jpg'), \
                                      load_image('./data/train/3/989.jpg'), \
                                      load_image('./data/validation/3/998.jpg')
                                     ]))

for predict_index, predicted_y in enumerate(predictions):
    predicted_label = np.argmax(predicted_y)
    print(category_map[predicted_label])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-64fe4ed516d7> in <module>()
#       4 for predict_index, predicted_y in enumerate(predictions):
#       5     predicted_label = np.argmax(predicted_y)
# ----> 6     print(category_map[predicted_label])
#
# KeyError: 50

# %%
batch_size = 32
img_height, img_width = 299, 299

validation_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = validation_datagen.flow_from_directory(
        'data/validation',
        target_size=(img_height, img_width),
        batch_size=batch_size)
# Out:
# Found 7331 images belonging to 132 classes.

# %%
# Evaluate model with test data set and share sample prediction results
evaluation = model.evaluate_generator(validation_generator,
                                      steps=validation_generator.samples // batch_size,
                                      workers=4)
print('Model Accuracy = %.2f' % (evaluation[1]))
print('Model Loss = %.2f' % (evaluation[0]))
# Out:
# Model Accuracy = 0.74
# Model Loss = 0.99
